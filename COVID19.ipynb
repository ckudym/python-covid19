# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %%
df = pd.read_csv("data/coronavirus/full_data_2020-03-18.csv")
print(df.dtypes)
print(df.head())
# Out:
# date             object
# location         object
# new_cases       float64
# new_deaths      float64
# total_cases       int64
# total_deaths    float64
# dtype: object
#          date     location  new_cases  new_deaths  total_cases  total_deaths
# 0  2020-02-25  Afghanistan        NaN         NaN            1           NaN
# 1  2020-02-26  Afghanistan        0.0         NaN            1           NaN
# 2  2020-02-27  Afghanistan        0.0         NaN            1           NaN
# 3  2020-02-28  Afghanistan        0.0         NaN            1           NaN
# 4  2020-02-29  Afghanistan        0.0         NaN            1           NaN

# %%
df['date'] = pd.to_datetime(df['date'])
df.sort_values('date', inplace=True)
df.head(40)
# Out:
#            date       location  new_cases  new_deaths  total_cases  \
# 1994 2020-01-21    South Korea        NaN         NaN            1
# 1318 2020-01-21          Japan        NaN         NaN            1
# 2489 2020-01-21       Thailand        NaN         NaN            2
# 498  2020-01-21          China        NaN         NaN          278
# 2810 2020-01-21          World        0.0         0.0          282
# 1995 2020-01-22    South Korea        0.0         NaN            1
# 2490 2020-01-22       Thailand        0.0         NaN            2
# 499  2020-01-22          China       32.0         0.0          310
# 2811 2020-01-22          World       32.0         0.0          314
# 1319 2020-01-22          Japan        0.0         NaN            1
# 1996 2020-01-23    South Korea        0.0         NaN            1
# 2693 2020-01-23  United States        NaN         NaN            1
# 1320 2020-01-23          Japan        0.0         NaN            1
# ...

# %%
locations = ['United States', 'Italy', 'South Korea', 'France']
for location in locations: 
    day = df['date']
    country = df['location']
    newCases = df['new_cases']
    newDeaths = df['new_deaths']
    totalCases = df['total_cases']
    totalDeaths = df['total_deaths']

# %%
plt.plot_date(day, newDeaths, linestyle="solid")

# %%
df[['new_cases', 'new_deaths']].plot()

# %%
print(df.head())
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths  \
# 0  2020-02-25  Afghanistan        NaN         NaN            1           NaN
# 1  2020-02-26  Afghanistan        0.0         NaN            1           NaN
# 2  2020-02-27  Afghanistan        0.0         NaN            1           NaN
# 3  2020-02-28  Afghanistan        0.0         NaN            1           NaN
# 4  2020-02-29  Afghanistan        0.0         NaN            1           NaN
#
#         Time
# 0 2020-02-25
# 1 2020-02-26
# 2 2020-02-27
# 3 2020-02-28
# 4 2020-02-29
